# %% [markdown]
# https://www.acmicpc.net/problem/1260

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-16%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.35.27.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202022-06-16%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%204.35.27.png)

# %%
'''
5 5 3
5 4
5 2
1 2
3 4
3 1
'''
# Out:
# '\n5 5 3\n5 4\n5 2\n1 2\n3 4\n3 1\n'

# %%
# 그래프 그려보기

N, M, V = map(int, input().split())
# Out:
# 5 5 3

# %%
graph = [[] for _ in range(N+1)]
graph
# Out:
# [[], [], [], [], [], []]

# %%
'''
5 5 3
5 4
5 2
1 2
3 4
3 1
'''
for i in range(M):
    a, b = map(int, input().split())
    graph[a].append(b)
    graph[b].append(a)
# Out:
# 5 4
# 5 2
# 1 2
# 3 4
# 3 1

# %%
graph
# Out:
# [[], [2, 3], [5, 1], [4, 1], [5, 3], [4, 2]]

# %%
for i in range(N+1):
    graph[i].sort()

# %%
graph
# Out:
# [[], [2, 3], [1, 5], [1, 4], [3, 5], [2, 4]]
